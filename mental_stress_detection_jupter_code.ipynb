# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# Load dataset
df = pd.read_csv("Dateset (3).csv")

# %%
df
# Out:
#      1. Age 2. Gender                                      3. University  \
# 0     18-22    Female           Independent University, Bangladesh (IUB)
# 1     18-22      Male           Independent University, Bangladesh (IUB)
# 2     18-22      Male  American International University Bangladesh (...
# 3     18-22      Male  American International University Bangladesh (...
# 4     18-22      Male                       North South University (NSU)
# ...     ...       ...                                                ...
# 9995  18-22    Female           Bangladesh Agricultural University (BAU)
# 9996  27-30      Male  Bangladesh University of Engineering and Techn...
# 9997  23-26    Female           Independent University, Bangladesh (IUB)
# 9998  23-26      Male                              Dhaka University (DU)
# 9999  23-26      Male                              Dhaka University (DU)
#
#                                      4. Department           5. Academic Year  \
# ...

# %%
# Display basic info
display(df.head())
display(df.info())
# Out:
#   1. Age 2. Gender                                      3. University  \
# 0  18-22    Female           Independent University, Bangladesh (IUB)
# 1  18-22      Male           Independent University, Bangladesh (IUB)
# 2  18-22      Male  American International University Bangladesh (...
# 3  18-22      Male  American International University Bangladesh (...
# 4  18-22      Male                       North South University (NSU)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 3  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 4  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
#
#   6. Current CGPA  \
# 0     2.50 - 2.99
# 1     3.00 - 3.39
# 2     3.00 - 3.39
# ...

# %%
# Step 1: Clean column names
df.columns = df.columns.str.strip()

# %%
df.head(1)
# Out:
#   1. Age 2. Gender                             3. University  \
# 0  18-22    Female  Independent University, Bangladesh (IUB)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
#
#   6. Current CGPA  \
# 0     2.50 - 2.99
#
#   7. Did you receive a waiver or scholarship at your university?  \
# 0                                                 No
#
#   1. In a semester, how often have you felt upset due to something that happened in your academic affairs?  \
# 0                                   3 - Fairly Often
#
#   2. In a semester, how often you felt as if you were unable to control important things in your academic affairs?  \
# 0                                     4 - Very Often
#
#   3. In a semester, how often you felt nervous and stressed because of academic pressure?  \
# 0                                   3 - Fairly Often
#
#    ...  \
# 0  ...
#
# ...

# %%
# Magacyada columns-ka kahor isbeddelka
print("Magacyada Column-yada Kahor Beddelka:\n", df.columns)

# Magacyada cusub ee la soo gaabiyey
new_column_names = {
    "1. Age": "Age",
    "2. Gender": "Gender",
    "3. University": "University",
    "4. Department": "Department",
    "5. Academic Year": "Academic_Year",
    "6. Current CGPA": "Current_CGPA",
    "7. Did you receive a waiver or scholarship at your university?": "Scholarship",
    
    # Su'aalaha la xiriira Academic Stress
    "1. In a semester, how often have you felt upset due to something that happened in your academic affairs?": "Upset_Academic",
    "2. In a semester, how often you felt as if you were unable to control important things in your academic affairs?": "No_Control_Academic",
    "3. In a semester, how often you felt nervous and stressed because of academic pressure?": "Nervous_Stress_Academic",
    "7. In a semester, how often have you felt afraid, as if something awful might happen?": "Afraid_Academic",
    
    # Su'aalaha la xiriira Psychological Stress
    "1. In a semester, how often have you had little interest or pleasure in doing things?": "Low_Interest",
    "2. In a semester, how often have you been feeling down, depressed or hopeless?": "Depressed",
    "3. In a semester, how often have you had trouble falling or staying asleep, or sleeping too much?": "Sleep_Issue",
    "4. In a semester, how often have you been feeling tired or having little energy?": "Low_Energy",
    "5. In a semester, how often have you had poor appetite or overeating?": "Appetite_Issue",
    "6. In a semester, how often have you been feeling bad about yourself - or that you are a failure or have let yourself or your family down?": "Low_SelfEsteem",
    "7. In a semester, how often have you been having trouble concentrating on things, such as reading the books or watching television?": "Concentration_Issue",
    "8. In a semester, how often have you moved or spoke too slowly for other people to notice? Or you've been moving a lot more than usual because you've been restless?": "Motor_Change",
    "9. In a semester, how often have you had thoughts that you would be better off dead, or of hurting yourself?": "Suicidal_Thoughts",
    "4. In a semester, how often you felt as if you could not cope with all the mandatory academic activities? (e.g, assignments, quiz, exams)": "Cope_Academic",
    "5. In a semester, how often you felt confident about your ability to handle your academic / university problems?": "Confident_Academic",
    "6. In a semester, how often you felt as if things in your academic life is going on your way?": "Academic_Going_Well",
    "7. In a semester, how often are you able to control irritations in your academic / university affairs?": "Irritation_Control",
    "8. In a semester, how often you felt as if your academic performance was on top?": "Top_Performance",
    "9. In a semester, how often you got angered due to bad performance or low grades that is beyond your control?": "Anger_LowGrades",
    "10. In a semester, how often you felt as if academic difficulties are piling up so high that you could not overcome them?": "Overwhelmed_Difficulties",
    "1. In a semester, how often you felt nervous, anxious or on edge due to academic pressure?": "Nervous_Anxiety",
    "2. In a semester, how often have you been unable to stop worrying about your academic affairs?": "Worry_Academic",
    "3. In a semester, how often have you had trouble relaxing due to academic pressure?": "Relax_Trouble",
    "4. In a semester, how often have you been easily annoyed or irritated because of academic pressure?": "Irritated_Academic",
    "5. In a semester, how often have you worried too much about academic affairs?": "Excessive_Worry",
    "6. In a semester, how often have you been so restless due to academic pressure that it is hard to sit still?": "Restless_Academic",

}
# Hubinta isbeddelka
print("\nMagacyada Column-yada Kadib Beddelka:\n", df.columns)


# Beddelida magacyada column-yada
df.rename(columns=new_column_names, inplace=True)
# Haddii aad rabto inaad dib u keydiso dataset-ka cusub
new_file_path = r"C:\Users\hp\Documents\mental_stress_data_analaysis\shortcolumsdatest.csv"

df.to_csv(new_file_path, index=False)

print("\nXogta cusub waa la keydiyay! Waxaad ka heli kartaa:", new_file_path)
# Out:
# Magacyada Column-yada Kahor Beddelka:
#  Index(['Age', 'Gender', 'University', 'Department', 'Academic_Year',
#        'Current_CGPA', 'Scholarship', 'Upset_Academic', 'No_Control_Academic',
#        'Nervous_Stress_Academic', 'Cope_Academic', 'Confident_Academic',
#        'Academic_Going_Well', 'Irritation_Control', 'Top_Performance',
#        'Anger_LowGrades', 'Overwhelmed_Difficulties', 'Nervous_Anxiety',
#        'Worry_Academic', 'Relax_Trouble', 'Irritated_Academic',
#        'Excessive_Worry', 'Restless_Academic', 'Afraid_Academic',
#        'Low_Interest', 'Depressed', 'Sleep_Issue', 'Low_Energy',
#        'Appetite_Issue', 'Low_SelfEsteem', 'Concentration_Issue',
#        'Motor_Change', 'Suicidal_Thoughts'],
#       dtype='object')
#
# Magacyada Column-yada Kadib Beddelka:
#  Index(['Age', 'Gender', 'University', 'Department', 'Academic_Year',
#        'Current_CGPA', 'Scholarship', 'Upset_Academic', 'No_Control_Academic',
# ...

# %%
df
# Out:
#         Age  Gender                                         University  \
# 0     18-22  Female           Independent University, Bangladesh (IUB)
# 1     18-22    Male           Independent University, Bangladesh (IUB)
# 2     18-22    Male  American International University Bangladesh (...
# 3     18-22    Male  American International University Bangladesh (...
# 4     18-22    Male                       North South University (NSU)
# ...     ...     ...                                                ...
# 9995  18-22  Female           Bangladesh Agricultural University (BAU)
# 9996  27-30    Male  Bangladesh University of Engineering and Techn...
# 9997  23-26  Female           Independent University, Bangladesh (IUB)
# 9998  23-26    Male                              Dhaka University (DU)
# 9999  23-26    Male                              Dhaka University (DU)
#
#                                         Department              Academic_Year  \
# ...

# %%
shortdf=pd.read_csv("shortcolumsdatest.csv")
shortdf.head(3)
# Out:
#      Age  Gender                                         University  \
# 0  18-22  Female           Independent University, Bangladesh (IUB)
# 1  18-22    Male           Independent University, Bangladesh (IUB)
# 2  18-22    Male  American International University Bangladesh (...
#
#                                      Department              Academic_Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
#
#   Current_CGPA Scholarship    Upset_Academic No_Control_Academic  \
# 0  2.50 - 2.99          No  3 - Fairly Often      4 - Very Often
# 1  3.00 - 3.39          No  3 - Fairly Often    3 - Fairly Often
# 2  3.00 - 3.39          No         0 - Never           0 - Never
#
#   Nervous_Stress_Academic  ...              Afraid_Academic  \
# 0        3 - Fairly Often  ...  2 - More than half the days
# ...
